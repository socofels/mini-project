# %% [markdown]
# # 第一次使用jupyter笔记本

# %% [markdown]
# # * 安装
# 在电脑安装python3.7后，在终端输入命令进行安装
#
# 使用PIP命令安装| pip install jupyter
# :-|:-
# 启动jupyter终端输入|jupyter notebook
#
# 启动后自动打开页面

# %% [markdown]
# ### 新建一个笔记本
# ![image.png](attachment:image.png)

# %% [markdown]
# ### 修改笔记本名称
# ![image.png](attachment:image.png)

# %% [markdown]
# ### 首先需要了解的快捷键操作，在命令模式“蓝色框框”下的一些操作
# ![image.png](attachment:image.png)

# %% [markdown]
# ### 需要了解到的编辑模式下操作"绿色框框"下的操作
# ![image.png](attachment:image.png)

# %% [markdown]
# ### 四种cell的类型
# code 写代码
# markdown 写笔记
# nbconvert 里面的代码文字都不会运行
# heading 标题，已经包含在markdown中 ####

# %% [markdown]
# ### markdown常见用法
# ![image.png](attachment:image.png)

# %% [markdown]
# ### 表格的使用
# ：表示对齐位置
# :-左对齐 :-:居中 -:右对齐
#
# |表格|测试|333|
# |:-|:-:|-:|
# |第二行||22|123|
# |1|2|2|

# %% [markdown]
# ### 使用魔法函数
# 魔法函数|作用
# :-|:-
# %%writefile|调用外部python脚本
# %run|调用外部python脚本
# %timeit|测试单行语句的执行时间
# %%timeit|测试整个单元中代码的执行时间
# % matplotlib inline|显示 matplotlib 包生成的图形
# %%writefile|写入文件
# %pdb|调试程序
# %pwd|查看当前工作目录
# %ls|查看目录文件列表
# %reset|清除全部变量
# %who|查看所有全局变量的名称，若给定类型参数，只返回该类型的变量列表
# %whos|显示所有的全局变量名称、类型、值/信息
# %xmode Plain|设置为当异常发生时只展示简单的异常信息
# %xmode Verbose|设置为当异常发生时展示详细的异常信息
# %debug|bug调试，输入quit退出调试
# %env|列出全部环境变量

# %% [markdown]
# ### 使用TAB 可以代码补全
# ![image.png](attachment:image.png)

# %%
from datetime import datetime
datetime.now()
# Out:
# datetime.datetime(2019, 9, 12, 19, 0, 37, 767830)

# %% [markdown]
# ### 使用分号; 可以使本行内容不进行输出

# %%
x = 99
x
# Out:
# 99

# %%
y = 100
y+1
y;

# %% [markdown]
# ### 不要在虚拟环境下安装，否则不能将文件放置根目录之外的地方
# 保存到根目录之外的目录时出现了这个
# ![image.png](attachment:image.png)

# %% [markdown]
# ### 保存为md文件的话，如果有截图要注意，可能会丢失
